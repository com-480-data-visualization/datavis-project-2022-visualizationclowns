# %%
import numpy as np
import pandas as pd
import random as rd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# We have a totoal of 15583 Tweets between the 2022-03-07 07:49:42 and 2010-06-04 18:31:57.
#
# The main data we have available for the data exploration is the date of the tweet, its contents as well as the number of likes, replies and retweets.

# %%
tweets = pd.read_csv("../tweets/alltweets.csv")
tweets.shape
# Out:
# (15583, 7)

# %% [markdown]
# We have 50 tweets that cointain the work bitcoin or BTC. This seems as not that much but we will se what we can make of it

# %%
bitcoin_tweets = tweets[tweets["tweet"].str.match(r".*([b,B]itcoin|BTC).*")].reset_index()
shape = bitcoin_tweets.shape
bitcoin_tweets.head(shape[0])
# Out:
#     index  Unnamed: 0                   id           created_at  \
# 0     710         710  1471583489824808972  2021-12-16 20:50:19
# 1    1039        1039  1461942451053252612  2021-11-20 06:20:16
# 2    1329        1329  1452334458066149377  2021-10-24 18:01:32
# 3    1332        1332  1452332044743323654  2021-10-24 17:51:57
# 4    2114        2114  1420529868404518913  2021-07-28 23:41:27
# 5    2208        2208  1417207016519454724  2021-07-19 19:37:37
# 6    2209        2209  1417204066552205332  2021-07-19 19:25:54
# 7    2336        2336  1413396249546563586  2021-07-09 07:15:00
# 8    2512        2512  1408246534093918210  2021-06-25 02:11:52
# 9    2513        2513  1408246196603346947  2021-06-25 02:10:31
# 10   2515        2515  1408244494567456769  2021-06-25 02:03:46
# 11   2556        2556  1405482221666852871  2021-06-17 11:07:28
# 12   2590        2590  1404132183254523905  2021-06-13 17:42:54
# 13   2628        2628  1401662959923994625  2021-06-06 22:11:05
# ...

# %% [markdown]
# We have 120 tweets with Doge in the tweets.

# %%
dogecoin_tweets = tweets[tweets["tweet"].str.match(r".*((D|d)(O|o)(G|g)(E|e)).*")].reset_index()
dogecoin_tweets.head(dogecoin_tweets.shape[0])
# Out:
#      index  Unnamed: 0                   id           created_at  \
# 0        1           1  1500730165239988227  2022-03-07 07:08:48
# 1        2           2  1500635105953419265  2022-03-07 00:51:04
# 2       76          76  1498870920383025161  2022-03-02 04:00:49
# 3      160         160  1495824937269055495  2022-02-21 18:17:10
# 4      420         420  1486768360025174020  2022-01-27 18:29:34
# ..     ...         ...                  ...                  ...
# 115   6221        6221  1254039929333649409  2020-04-25 13:29:52
# 116   9463        9463  1113178951403180032  2019-04-02 20:38:38
# 117   9464        9464  1113173498384441344  2019-04-02 20:16:58
# 118   9465        9465  1113164389929160706  2019-04-02 19:40:46
# 119   9466        9466  1113009339743100929  2019-04-02 09:24:39
#
#                                                  tweet  nlikes  nreplies  \
# 0    @hiromichimizuno @GailAlfarATX @Tesla @TeslaSo...    1399       214
# ...

# %% [markdown]
# We have 2988 tweets with TSLA or Tesla in the tweets.

# %%
tsla_tweets = tweets[tweets["tweet"].str.match(r".*((T|t)(S|es)(L|l)(A|a)).*")].reset_index()
tsla_tweets.head(tsla_tweets.shape[0])
# Out:
#       index  Unnamed: 0                   id           created_at  \
# 0         1           1  1500730165239988227  2022-03-07 07:08:48
# 1         2           2  1500635105953419265  2022-03-07 00:51:04
# 2         3           3  1500622046987882504  2022-03-06 23:59:10
# 3        12          12  1500471082750414848  2022-03-06 13:59:18
# 4        18          18  1500342231353290755  2022-03-06 05:27:17
# ...     ...         ...                  ...                  ...
# 2983  15518       15518   159330976378519552  2012-01-17 17:47:19
# 2984  15519       15519   159330380955136001  2012-01-17 17:44:57
# 2985  15522       15522   157700726515183616  2012-01-13 05:49:17
# 2986  15526       15526   156927468836630528  2012-01-11 02:36:39
# 2987  15542       15542   153099684280410112  2011-12-31 13:06:23
#
#                                                   tweet  nlikes  nreplies  \
# 0     @hiromichimizuno @GailAlfarATX @Tesla @TeslaSo...    1399       214
# ...

# %%
tweets[tweets["tweet"].str.match(r".*((S|s)(E|e)(L|l)(L|l)).*")].reset_index().head(200)
# Out:
#     index  Unnamed: 0                   id           created_at  \
# 0    1112        1112  1459904966194253824  2021-11-14 15:24:02
# 1    1185        1185  1457067398712942592  2021-11-06 19:28:33
# 2    1188        1188  1457064697782489088  2021-11-06 19:17:49
# 3    1217        1217  1455351085170823169  2021-11-02 01:48:32
# 4    1247        1247  1454808104256737289  2021-10-31 13:50:55
# ..    ...         ...                  ...                  ...
# 70  14226       14226   715934657720639488  2016-04-01 16:11:38
# 71  14577       14577   577533623483568128  2015-03-16 18:15:20
# 72  15141       15141   322170049316139009  2013-04-11 02:11:40
# 73  15146       15146   321637861147426816  2013-04-09 14:56:56
# 74  15517       15517   159396536621596672  2012-01-17 22:07:50
#
#                                                 tweet  nlikes  nreplies  \
# 0   @SenSanders Want me to sell more stock, Bernie...  130457     11855
# ...
